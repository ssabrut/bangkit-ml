# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.layers import Dense
from keras.layers import Flatten
import math

# %%
data= pd.read_excel('ML_predicion_harga.xlsx')
print(data.head())
# Out:
#         Daerah  tahun      tanaman  Luas panen (ha)  produksi (kuintal)  \
# 0      Pacitan   2020  Cabai Rawit            259.0              8252.0
# 1     Ponorogo   2020  Cabai Rawit            467.0             20335.0
# 2   Trenggalek   2020  Cabai Rawit            411.0             10378.0
# 3  Tulungagung   2020  Cabai Rawit            239.0              9491.0
# 4       Blitar   2020  Cabai Rawit          10745.0           1881377.0
#
#    harga (/kg)
# 0        18000
# 1        13500
# 2        14500
# 3        14666
# 4        14500

# %%
data.head()
# Out:
#         Daerah  tahun      tanaman  Luas panen (ha)  produksi (kuintal)  \
# 0      Pacitan   2020  Cabai Rawit            259.0              8252.0
# 1     Ponorogo   2020  Cabai Rawit            467.0             20335.0
# 2   Trenggalek   2020  Cabai Rawit            411.0             10378.0
# 3  Tulungagung   2020  Cabai Rawit            239.0              9491.0
# 4       Blitar   2020  Cabai Rawit          10745.0           1881377.0
#
#    harga (/kg)
# 0        18000
# 1        13500
# 2        14500
# 3        14666
# 4        14500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Daerah              465 non-null    object
#  1   tahun               465 non-null    int64
#  2   tanaman             465 non-null    object
#  3   Luas panen (ha)     465 non-null    float64
#  4   produksi (kuintal)  465 non-null    float64
#  5   harga (/kg)         465 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 21.9+ KB

# %%
# Daftar kategori unik dalam kolom "tanaman" dan "Daerah"
unique_tanaman = data['tanaman'].unique()
unique_daerah = data['Daerah'].unique()

# Membuat kamus pemetaan kategori ke nilai numerik
tanaman_mapping = {tanaman: i for i, tanaman in enumerate(unique_tanaman)}
daerah_mapping = {daerah: i for i, daerah in enumerate(unique_daerah)}

# Mengganti nilai kategori dengan nilai numerik menggunakan metode replace()
data['tanaman'] = data['tanaman'].replace(tanaman_mapping)
data['Daerah'] = data['Daerah'].replace(daerah_mapping)

# %%
print(data['tanaman'].unique())
# Out:
# [0 1 2 3 4]

# %%
# Visualisasi kolom 'harga (/kg)' untuk setiap jenis tanaman
plt.figure(figsize=(16, 8))
plt.title('Harga Tiap Tanaman')

tanaman_mapping = {0: 'Cabai Rawit', 1: 'Bawang Merah', 2: 'Bawang Putih', 3: 'Kentang', 4: 'Kubis'}

for tanaman_id, tanaman_label in tanaman_mapping.items():
    filtered_data = data[data['tanaman'] == tanaman_id]
    plt.plot(filtered_data['harga (/kg)'], marker='o', label=tanaman_label)

plt.xlabel('Indeks Data', fontsize=18)
plt.ylabel('Harga (/kg)', fontsize=18)
plt.legend()
plt.show()

# %%
# Membuat dataframe baru dengan kolom yang berpengaruh
relevant_columns = ['Daerah', 'tahun', 'tanaman', 'Luas panen (ha)', 'produksi (kuintal)', 'harga (/kg)']
data = data[relevant_columns]

# Mengambil kolom 'daerah' dan 'tanaman' sebagai kategori (tidak ikut scaling dan normalisasi)
kategori_data = data[['Daerah', 'tahun', 'tanaman']]

# Mengambil kolom-kolom numerik untuk scaling dan normalisasi
numeric_data = data.drop(['Daerah', 'tahun', 'tanaman', 'harga (/kg)'], axis=1)

# harga data
harga_data = data[["harga (/kg)"]]

# Scaling dan normalisasi
scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(harga_data)

# Menggabungkan kembali kolom-kolom yang telah diubah dan yang tidak ikut diubah
scaled_data = pd.DataFrame(scaled_numeric_data, columns=harga_data.columns)
scaled_dataset = pd.concat([kategori_data, numeric_data], axis=1)
scaled_dataset = pd.concat([scaled_dataset, scaled_data], axis=1)

# hasil scaling dan normalisasi
print("Data setelah scaling dan normalisasi:")
print(scaled_dataset)
# scaled_dataset
# Out:
# Data setelah scaling dan normalisasi:
#      Daerah  tahun  tanaman  Luas panen (ha)  produksi (kuintal)  harga (/kg)
# 0         0   2020        0            259.0            8252.000     0.192349
# 1         1   2020        0            467.0           20335.000     0.128587
# 2         2   2020        0            411.0           10378.000     0.142756
# 3         3   2020        0            239.0            9491.000     0.145108
# 4         4   2020        0          10745.0         1881377.000     0.142756
# ..      ...    ...      ...              ...                 ...          ...
# 460      26   2022        4             -1.0              -1.000     0.078994
# 461      27   2022        4              1.0             210.000     0.036486
# 462      28   2022        4             -1.0              -1.000     0.050655
# 463      29   2022        4             -1.0              -1.000     0.078994
# 464      30   2022        4            246.0              44.241     0.078994
#
# [465 rows x 6 columns]

# %%
# Mengonversi data ke dalam array numpy
X = scaled_dataset[['Daerah', 'tahun', 'tanaman', 'Luas panen (ha)', 'produksi (kuintal)']].values
y = scaled_dataset['harga (/kg)'].values

# Menghitung jumlah baris untuk melatih model (80%)
training_data_len = math.ceil(len(scaled_dataset) * 0.8)

# mengitung jumlah baris untuk melatih model (20%)
test_data_len = math.ceil(len(scaled_dataset) * 0.2)

X_train = X[:training_data_len]
y_train = y[:training_data_len]

X_test = X[training_data_len:]
y_test = y[training_data_len:]

print("Jumlah data latih:", training_data_len)
# Out:
# Jumlah data latih: 372

# %%
# Periksa nama kolom yang tersedia dalam DataFrame data
print(data.columns)
# Out:
# Index(['Daerah', 'tahun', 'tanaman', 'Luas panen (ha)', 'produksi (kuintal)',
#        'harga (/kg)'],
#       dtype='object')

# %%
# Create training dataset using sliding window approach
window_size = 60
x_train = []
y_train = []
for i in range(window_size, len(X_train)):
    x_train.append(X_train[i-window_size:i])
    y_train.append(y[i])  # Menggunakan y sebagai variabel target

# Convert to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape y_train to have the same number of dimensions as y_test
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# Print shape of the training dataset
print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)
x_train[0][0]
# Out:
# Shape of x_train: (312, 60, 5)
# Shape of y_train: (312, 1)
# array([   0., 2020.,    0.,  259., 8252.])

# %%
x_train = np.array(x_train)
print(x_train.shape)
# Out:
# (312, 60, 5)

# %%
# Membuat model MLP
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

# %%
# Compile dan latih model
from sklearn import metrics
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 5ms/step - loss: 401997056.0000 - accuracy: 0.0032
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 133187376.0000 - accuracy: 0.0000e+00
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 21973394.0000 - accuracy: 3.7393e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10515152.0000 - accuracy: 0.0023
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6614385.0000 - accuracy: 3.7393e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1719262.2500 - accuracy: 0.0028
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 440422.9688 - accuracy: 0.0017
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 184821.7969 - accuracy: 0.0011
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 102903.4766 - accuracy: 8.0128e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 45104.5586 - accuracy: 0.0011
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 29069.9043 - accuracy: 0.0012
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 20234.0566 - accuracy: 8.5470e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 5ms/step - loss: 16949.8262 - accuracy: 0.0014
# Epoch 14/100
# 10/10 [==============================] - 0s 5ms/step - loss: 15054.9473 - accuracy: 7.4786e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 14688.5225 - accuracy: 0.0012
# Epoch 16/100
# 10/10 [==============================] - 0s 4ms/step - loss: 15036.5146 - accuracy: 6.4103e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 14115.8330 - accuracy: 0.0012
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 14360.7549 - accuracy: 9.0812e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 13790.6719 - accuracy: 9.0812e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 5ms/step - loss: 13217.3701 - accuracy: 9.0812e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 5ms/step - loss: 13301.6699 - accuracy: 8.5470e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 5ms/step - loss: 12973.2773 - accuracy: 8.0128e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 5ms/step - loss: 12429.4668 - accuracy: 8.0128e-04
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 10789.7441 - accuracy: 6.9444e-04
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9163.8760 - accuracy: 0.0010
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7252.6323 - accuracy: 9.0812e-04
# Epoch 27/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5590.9780 - accuracy: 4.2735e-04
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 3844.3767 - accuracy: 5.8761e-04
# Epoch 29/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2395.7673 - accuracy: 4.8077e-04
# Epoch 30/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1261.8195 - accuracy: 8.5470e-04
# Epoch 31/100
# 10/10 [==============================] - 0s 5ms/step - loss: 635.7398 - accuracy: 9.6154e-04
# Epoch 32/100
# 10/10 [==============================] - 0s 8ms/step - loss: 352.7813 - accuracy: 9.6154e-04
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 211.6840 - accuracy: 0.0012
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 139.9624 - accuracy: 0.0011
# Epoch 35/100
# 10/10 [==============================] - 0s 5ms/step - loss: 116.3658 - accuracy: 0.0012
# Epoch 36/100
# 10/10 [==============================] - 0s 5ms/step - loss: 100.8454 - accuracy: 0.0013
# Epoch 37/100
# 10/10 [==============================] - 0s 5ms/step - loss: 90.3269 - accuracy: 0.0012
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 81.3529 - accuracy: 0.0013
# Epoch 39/100
# 10/10 [==============================] - 0s 5ms/step - loss: 74.0592 - accuracy: 0.0013
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 68.2181 - accuracy: 0.0014
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 63.4982 - accuracy: 0.0015
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 59.9571 - accuracy: 0.0014
# Epoch 43/100
# 10/10 [==============================] - 0s 7ms/step - loss: 56.7444 - accuracy: 0.0014
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 53.0652 - accuracy: 0.0017
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 49.1125 - accuracy: 0.0016
# Epoch 46/100
# 10/10 [==============================] - 0s 4ms/step - loss: 45.8330 - accuracy: 0.0015
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 42.9794 - accuracy: 0.0017
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 40.4939 - accuracy: 0.0016
# Epoch 49/100
# 10/10 [==============================] - 0s 4ms/step - loss: 38.1486 - accuracy: 0.0016
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 35.7631 - accuracy: 0.0017
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 33.8390 - accuracy: 0.0019
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 31.9395 - accuracy: 0.0018
# Epoch 53/100
# 10/10 [==============================] - 0s 5ms/step - loss: 30.1481 - accuracy: 0.0017
# Epoch 54/100
# 10/10 [==============================] - 0s 5ms/step - loss: 28.5016 - accuracy: 0.0018
# Epoch 55/100
# 10/10 [==============================] - 0s 5ms/step - loss: 27.0895 - accuracy: 0.0018
# Epoch 56/100
# 10/10 [==============================] - 0s 6ms/step - loss: 25.7425 - accuracy: 0.0018
# Epoch 57/100
# 10/10 [==============================] - 0s 5ms/step - loss: 24.5769 - accuracy: 0.0019
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 23.4912 - accuracy: 0.0018
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 22.5816 - accuracy: 0.0018
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 21.6160 - accuracy: 0.0017
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 20.7601 - accuracy: 0.0018
# Epoch 62/100
# 10/10 [==============================] - 0s 7ms/step - loss: 20.0030 - accuracy: 0.0018
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 19.3214 - accuracy: 0.0018
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 18.7001 - accuracy: 0.0017
# Epoch 65/100
# 10/10 [==============================] - 0s 7ms/step - loss: 18.0858 - accuracy: 0.0018
# Epoch 66/100
# 10/10 [==============================] - 0s 7ms/step - loss: 17.5220 - accuracy: 0.0018
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 16.9990 - accuracy: 0.0018
# Epoch 68/100
# 10/10 [==============================] - 0s 8ms/step - loss: 16.5565 - accuracy: 0.0017
# Epoch 69/100
# 10/10 [==============================] - 0s 8ms/step - loss: 16.0889 - accuracy: 0.0019
# Epoch 70/100
# 10/10 [==============================] - 0s 7ms/step - loss: 15.7490 - accuracy: 0.0019
# Epoch 71/100
# 10/10 [==============================] - 0s 8ms/step - loss: 15.3796 - accuracy: 0.0019
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 14.8974 - accuracy: 0.0016
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 14.4897 - accuracy: 0.0018
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 14.1495 - accuracy: 0.0015
# Epoch 75/100
# 10/10 [==============================] - 0s 9ms/step - loss: 13.8015 - accuracy: 0.0015
# Epoch 76/100
# 10/10 [==============================] - 0s 9ms/step - loss: 13.4635 - accuracy: 0.0017
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 13.1491 - accuracy: 0.0014
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 12.8560 - accuracy: 0.0015
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 12.5576 - accuracy: 0.0015
# Epoch 80/100
# 10/10 [==============================] - 0s 10ms/step - loss: 12.2873 - accuracy: 0.0014
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 12.0930 - accuracy: 0.0014
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 11.7841 - accuracy: 0.0013
# Epoch 83/100
# 10/10 [==============================] - 0s 7ms/step - loss: 11.5182 - accuracy: 0.0014
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 11.3234 - accuracy: 0.0013
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 11.1439 - accuracy: 0.0015
# Epoch 86/100
# 10/10 [==============================] - 0s 7ms/step - loss: 10.8608 - accuracy: 0.0013
# Epoch 87/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.6739 - accuracy: 0.0012
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 10.4792 - accuracy: 0.0012
# Epoch 89/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.3020 - accuracy: 0.0012
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 10.1449 - accuracy: 0.0012
# Epoch 91/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.0003 - accuracy: 0.0012
# Epoch 92/100
# 10/10 [==============================] - 0s 7ms/step - loss: 10.1222 - accuracy: 8.0128e-04
# Epoch 93/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.3194 - accuracy: 0.0017
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.7736 - accuracy: 8.0128e-04
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 10.4873 - accuracy: 7.4786e-04
# Epoch 96/100
# 10/10 [==============================] - 0s 9ms/step - loss: 9.3356 - accuracy: 0.0012
# Epoch 97/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.2057 - accuracy: 0.0014
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.0389 - accuracy: 0.0012
# Epoch 99/100
# 10/10 [==============================] - 0s 9ms/step - loss: 8.9626 - accuracy: 0.0013
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 8.7480 - accuracy: 0.0014

# %%
#show model loss
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Membuat x_test dan y_test_actual
window_size = 60
x_test = []
y_test_actual = []
for i in range(window_size, len(X_test)):
    x_test.append(X_test[i-window_size:i, :5])  # Menggunakan hanya 5 kolom fitur
 # Menggunakan semua kolom fitur
    y_test_actual.append(y_test[i])

# x_test.shape
# y_test_actual
# Mengonversi data menjadi array numpy
x_test = np.array(x_test)
x_test.shape
# print(x_test)
# y_test_actual = np.array(y_test_actual)
# x_test

# # Mengubah dimensi x_test
# x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1]))  # Menggunakan 5 kolom fitur

# # Menggunakan model untuk melakukan prediksi pada data uji
# test_predictions = model.predict(x_test)
# test_predictions[0][0][0]

# # # Mengembalikan skala asli pada data prediksi
# test_predictions = scaler.inverse_transform(test_predictions[0])
# print(test_predictions[0])

x_test
# # Mengembalikan skala asli pada data aktual
# y_test_actual_scaled = scaler.inverse_transform(y_test_actual.reshape(-1, 1))

# # Menghitung RMSE
# test_rmse = np.sqrt(np.mean(np.square(test_predictions[0])))
# print("Testing RMSE:", test_rmse)
# Out:
# array([[[ 0.0000e+00,  2.0200e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 1.0000e+00,  2.0200e+03,  4.0000e+00,  1.2000e+02,
#           1.2687e+04],
#         [ 2.0000e+00,  2.0200e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         ...,
#         [ 2.6000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.7000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.8000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00]],
#
#        [[ 1.0000e+00,  2.0200e+03,  4.0000e+00,  1.2000e+02,
#           1.2687e+04],
#         [ 2.0000e+00,  2.0200e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 3.0000e+00,  2.0200e+03,  4.0000e+00,  6.1000e+01,
#           3.9870e+03],
#         ...,
#         [ 2.7000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.8000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.9000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00]],
#
#        [[ 2.0000e+00,  2.0200e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 3.0000e+00,  2.0200e+03,  4.0000e+00,  6.1000e+01,
#           3.9870e+03],
#         [ 4.0000e+00,  2.0200e+03,  4.0000e+00,  1.4700e+02,
#           3.5667e+04],
#         ...,
#         [ 2.8000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.9000e+01,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 3.0000e+01,  2.0210e+03,  4.0000e+00,  2.4000e+02,
#           4.3261e+01]],
#
#        ...,
#
#        [[ 3.0000e+01,  2.0200e+03,  4.0000e+00,  2.7000e+02,
#           4.8600e+04],
#         [ 0.0000e+00,  2.0210e+03,  4.0000e+00,  1.0000e+00,
#           7.5000e+01],
#         [ 1.0000e+00,  2.0210e+03,  4.0000e+00,  1.5900e+02,
#           1.7048e+01],
#         ...,
#         [ 2.5000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.6000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.7000e+01,  2.0220e+03,  4.0000e+00,  1.0000e+00,
#           2.1000e+02]],
#
#        [[ 0.0000e+00,  2.0210e+03,  4.0000e+00,  1.0000e+00,
#           7.5000e+01],
#         [ 1.0000e+00,  2.0210e+03,  4.0000e+00,  1.5900e+02,
#           1.7048e+01],
#         [ 2.0000e+00,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         ...,
#         [ 2.6000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.7000e+01,  2.0220e+03,  4.0000e+00,  1.0000e+00,
#           2.1000e+02],
#         [ 2.8000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00]],
#
#        [[ 1.0000e+00,  2.0210e+03,  4.0000e+00,  1.5900e+02,
#           1.7048e+01],
#         [ 2.0000e+00,  2.0210e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 3.0000e+00,  2.0210e+03,  4.0000e+00,  1.1700e+02,
#           2.0068e+01],
#         ...,
#         [ 2.7000e+01,  2.0220e+03,  4.0000e+00,  1.0000e+00,
#           2.1000e+02],
#         [ 2.8000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00],
#         [ 2.9000e+01,  2.0220e+03,  4.0000e+00, -1.0000e+00,
#          -1.0000e+00]]])
